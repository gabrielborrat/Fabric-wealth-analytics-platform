# %%
def get_widget_or_default(widget_name: str, default_value: str) -> str:
    try:
        return dbutils.widgets.get(widget_name)
    except Exception:
        return default_value

gold_run_id = get_widget_or_default("gold_run_id", "MANUAL_RUN")

SILVER_TABLE = "silver_mcc"
GOLD_TABLE   = "gold_dim_mcc"

print(f"gold_run_id  = {gold_run_id}")
print(f"SILVER_TABLE = {SILVER_TABLE}")
print(f"GOLD_TABLE   = {GOLD_TABLE}")
# Out:
# StatementMeta(, f8e72689-05d3-49bf-9a08-4fb9b639909f, 3, Finished, Available, Finished)
# gold_run_id  = MANUAL_RUN
# SILVER_TABLE = silver_mcc
# GOLD_TABLE   = gold_dim_mcc

# %%
#-------------------------------
# Silver Contract first
#-------------------------------

from pyspark.sql import functions as F

CONTRACT = {
  "natural_key": ["mcc_code"],
  "business_columns": [
    ("mcc_code","STRING",False),
    ("mcc_description","STRING",True),
  ],
  "technical_columns": [
    ("source_file","STRING",False),
    ("ingestion_date","DATE",False),
    ("ingestion_ts","TIMESTAMP",False),
    ("record_hash","STRING",False),
  ],
  "allow_additional_columns": False,
  "dedup": {
    "keys": ["mcc_code"],
    "order_by": "ingestion_ts",
    "strategy": "keep_latest"
  }
}

BUSINESS_COLS = [c[0] for c in CONTRACT["business_columns"]]
TECH_COLS     = [c[0] for c in CONTRACT["technical_columns"]]
EXPECTED_COLS = BUSINESS_COLS + TECH_COLS
# Out:
# StatementMeta(, f8e72689-05d3-49bf-9a08-4fb9b639909f, 4, Finished, Available, Finished)

# %%
#-------------------------------
# Lecture Silver + fail fast
#-------------------------------

df_silver = spark.table(SILVER_TABLE)

actual_cols = df_silver.columns
missing = sorted(list(set(EXPECTED_COLS) - set(actual_cols)))
extra   = sorted(list(set(actual_cols) - set(EXPECTED_COLS)))

if missing:
    raise ValueError(f"[FAIL FAST] Missing columns in {SILVER_TABLE}: {missing}")

if not CONTRACT["allow_additional_columns"] and extra:
    raise ValueError(f"[FAIL FAST] Additional columns not allowed in {SILVER_TABLE}: {extra}")

print(f"Schema validation OK for {SILVER_TABLE}. Column count = {len(actual_cols)}")
# Out:
# StatementMeta(, f8e72689-05d3-49bf-9a08-4fb9b639909f, 5, Finished, Available, Finished)
# Schema validation OK for silver_mcc. Column count = 6

# %%
#-------------------------------
# Projection Canonique + cast 
#-------------------------------

def cast_expr(col_name: str, spark_type: str):
    return F.col(col_name).cast(spark_type).alias(col_name)

select_exprs = []
for name, typ, _nullable in CONTRACT["business_columns"]:
    select_exprs.append(cast_expr(name, typ))

for name, typ, _nullable in CONTRACT["technical_columns"]:
    select_exprs.append(cast_expr(name, typ))

df_proj = df_silver.select(*select_exprs)
# Out:
# StatementMeta(, f8e72689-05d3-49bf-9a08-4fb9b639909f, 6, Finished, Available, Finished)

# %%
#-------------------------------
# Data Quality minimal
#-------------------------------

dq_null_cnt = df_proj.filter(F.col("mcc_code").isNull() | (F.trim(F.col("mcc_code")) == "")).count()
if dq_null_cnt > 0:
    raise ValueError(f"[FAIL FAST] mcc_code has null/empty values: count={dq_null_cnt}")
# Out:
# StatementMeta(, f8e72689-05d3-49bf-9a08-4fb9b639909f, 7, Finished, Available, Finished)

# %%
#-------------------------------
# Deduplication
#-------------------------------

from pyspark.sql.window import Window

w = Window.partitionBy(*CONTRACT["dedup"]["keys"]).orderBy(F.col(CONTRACT["dedup"]["order_by"]).desc())

df_dedup = (
    df_proj
    .withColumn("_rn", F.row_number().over(w))
    .filter(F.col("_rn") == 1)
    .drop("_rn")
)

dup_cnt = (
    df_dedup
    .groupBy("mcc_code")
    .count()
    .filter(F.col("count") > 1)
    .count()
)

if dup_cnt != 0:
    raise ValueError(f"[FAIL FAST] Deduplication failed: still have duplicates on mcc_code (count={dup_cnt})")

print(f"Dedup OK. Rows = {df_dedup.count()}")
# Out:
# StatementMeta(, f8e72689-05d3-49bf-9a08-4fb9b639909f, 8, Finished, Available, Finished)
# Dedup OK. Rows = 109

# %%
#-------------------------------
#Technical columns Gold  + Write 
#-------------------------------

df_gold = (
    df_dedup
    .withColumn("gold_run_id", F.lit(gold_run_id))
    .withColumn("gold_load_ts", F.current_timestamp())
)

spark.sql(f"TRUNCATE TABLE {GOLD_TABLE}")

(
    df_gold
    .write
    .mode("append")
    .format("delta")
    .saveAsTable(GOLD_TABLE)
)

print(f"Loaded {GOLD_TABLE} successfully.")
# Out:
# StatementMeta(, f8e72689-05d3-49bf-9a08-4fb9b639909f, 9, Finished, Available, Finished)
# Loaded gold_dim_mcc successfully.

# %%
#-------------------------------
#Post Load Control
#-------------------------------

spark.sql(f"""
SELECT
  count(*) AS row_count,
  max(gold_load_ts) AS last_gold_load_ts
FROM {GOLD_TABLE}
""").show(truncate=False)

spark.sql(f"SELECT * FROM {GOLD_TABLE} ORDER BY mcc_code LIMIT 50").show(truncate=False)
# Out:
# StatementMeta(, f8e72689-05d3-49bf-9a08-4fb9b639909f, 10, Finished, Available, Finished)
# +---------+--------------------------+
# |row_count|last_gold_load_ts         |
# +---------+--------------------------+
# |109      |2026-01-05 19:21:50.875575|
# +---------+--------------------------+
#
# +--------+-----------------------------------------------+-----------------------------+--------------+--------------------------+----------------------------------------------------------------+-----------+--------------------------+
# |mcc_code|mcc_description                                |source_file                  |ingestion_date|ingestion_ts              |record_hash                                                     |gold_run_id|gold_load_ts              |
# +--------+-----------------------------------------------+-----------------------------+--------------+--------------------------+----------------------------------------------------------------+-----------+--------------------------+
# |1711    |Heating, Plumbing, Air Conditioning Contractors|Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|0e282647e5a7fcb7be7dc7272d9fad90bcc9d3c69f264e5cab2940413782ce3a|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3000    |Steelworks                                     |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|e329b150edad34826ac2db874f66748e68b3daa9b14262a16a909ba4587eb14e|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3001    |Steel Products Manufacturing                   |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|6294cac7c468bae46bdc5d264c97027fd22f865a0b07cde1f9e1e48479a120a2|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3005    |Miscellaneous Metal Fabrication                |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|4b077bbe455a79fce00268add6e9e0f2bd3063f5c6f71c23f6aa9afa26b4dd05|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3006    |Miscellaneous Fabricated Metal Products        |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|6112667cdce43a48269763d25c95b8b9b5409f0c68ef0ce8eef8e7f4bafe2dac|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3007    |Coated and Laminated Products                  |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|902082a81783775ba154021f796347d1463686ba9cb0958bde7ad4801b023642|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3008    |Steel Drums and Barrels                        |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|dd5ac866eb8d6c08bd3f8b920499d2643faa2f60f8c18b884c0b230fb1a2a636|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3009    |Fabricated Structural Metal Products           |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|6ffc65048be3ec0c128abd78a14fbf7ada71ed18149f656558d3ebb95d12dd04|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3058    |Tools, Parts, Supplies Manufacturing           |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|d8f82f7c554909633add06e1a543564d04ba5c2d9f5bda4c592566ed0fe38228|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3066    |Miscellaneous Metals                           |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|6a9f218a3a474b646ee0995892038485803d442c2b10efa2b9214e4a4ac3e08e|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3075    |Bolt, Nut, Screw, Rivet Manufacturing          |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|d07b42ea6ac738a4203213b7a188ac1b3094c665e7399ed13b040457eb9eb776|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3132    |Leather Goods                                  |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|edd3d525ec7f9eadb1f52f9366dcf7f21fe53d4dd4c4b7905f05dda2e278c70b|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3144    |Floor Covering Stores                          |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|c8d39dbcbfeef3f0228a95f90276808772dc2881955f15716ea046ed6f554ebf|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3174    |Upholstery and Drapery Stores                  |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|be58065ef321e1656d864640fd094a63eb28ab7da9b693f7386978cf81006e01|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3256    |Brick, Stone, and Related Materials            |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|08d0a7eb2028e82e70b5b178b6e194cdb20dac9e5009ee63e676b9ba22c098f5|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3260    |Pottery and Ceramics                           |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|095e7833d75565c869a5b90a61855e0988e2176d6e1615a6877f09b1bba14a72|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3359    |Non-Ferrous Metal Foundries                    |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|993d79385ee00dea18eee62e31a4387cfc515ad9715ab573df573a601d1240e7|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3387    |Electroplating, Plating, Polishing Services    |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|a76b91907266a80826c98888ed505e5635daa584d4fc1812266cd58e19f1b509|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3389    |Non-Precious Metal Services                    |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|0498d914ffacf3b377a402cc081cd060251dc7d5fb9218438c7ba63768b6a577|MANUAL_RUN |2026-01-05 19:21:50.875575|
# |3390    |Miscellaneous Metalwork                        |Files/landing/mcc/2025-12-07/|2025-12-07    |2025-12-07 23:44:24.554925|3293f9cf8ab555977f403c7a2fb3648620437e3d92d526179985b1328baa2ebc|MANUAL_RUN |2026-01-05 19:21:50.875575|
# +--------+-----------------------------------------------+-----------------------------+--------------+--------------------------+----------------------------------------------------------------+-----------+--------------------------+
# only showing top 20 rows
